# %% [markdown]
# ##### DBFS e dbutils Documentação
# https://docs.databricks.com/pt/dbfs/index.html
#
# https://docs.databricks.com/pt/dev-tools/databricks-utils.html

# %% [markdown]
# ##### Arquitetura azure
#
# https://learn.microsoft.com/pt-br/azure/architecture/solution-ideas/articles/azure-databricks-modern-analytics-architecture
#
# https://learn.microsoft.com/pt-br/azure/architecture/solution-ideas/articles/ingest-etl-stream-with-adb

# %%
/dbfs/FileStore/tables/Clientes.csv

# %%
dbutils.help()
# Out:
# <div class = "ansiout">
# This module provides various utilities for users to interact with the rest of Databricks.
#   <h3></h3><b>credentials: DatabricksCredentialUtils</b> -> Utilities for interacting with credentials within notebooks<br /><b>data: DataUtils</b> -> Utilities for understanding and interacting with datasets (EXPERIMENTAL)<br /><b>fs: DbfsUtils</b> -> Manipulates the Databricks filesystem (DBFS) from the console<br /><b>jobs: JobsUtils</b> -> Utilities for leveraging jobs features<br /><b>library: LibraryUtils</b> -> Utilities for session isolated libraries<br /><b>meta: MetaUtils</b> -> Methods to hook into the compiler (EXPERIMENTAL)<br /><b>notebook: NotebookUtils</b> -> Utilities for the control flow of a notebook (EXPERIMENTAL)<br /><b>preview: Preview</b> -> Utilities under preview category<br /><b>secrets: SecretUtils</b> -> Provides utilities for leveraging secrets within notebooks<br /><b>widgets: WidgetsUtils</b> -> Methods to create and get bound value of input widgets inside notebooks<br /><br /></div>

# %%
dbutils.fs.help()
# Out:
# <div class = "ansiout"><b>dbutils.fs</b> provides utilities for working with FileSystems. Most methods in
# this package can take either a DBFS path (e.g., "/foo" or "dbfs:/foo"), or
# another FileSystem URI.
#
# For more info about a method, use <b>dbutils.fs.help("methodName")</b>.
#
# In notebooks, you can also use the %fs shorthand to access DBFS. The %fs shorthand maps
# straightforwardly onto dbutils calls. For example, "%fs head --maxBytes=10000 /file/path"
# translates into "dbutils.fs.head("/file/path", maxBytes = 10000)".
#     <h3>mount</h3><b>mount(source: String, mountPoint: String, encryptionType: String = "", owner: String = null, extraConfigs: Map = Map.empty[String, String]): boolean</b> -> Mounts the given source directory into DBFS at the given mount point<br /><b>mounts: Seq</b> -> Displays information about what is mounted within DBFS<br /><b>refreshMounts: boolean</b> -> Forces all machines in this cluster to refresh their mount cache, ensuring they receive the most recent information<br /><b>unmount(mountPoint: String): boolean</b> -> Deletes a DBFS mount point<br /><b>updateMount(source: String, mountPoint: String, encryptionType: String = "", owner: String = null, extraConfigs: Map = Map.empty[String, String]): boolean</b> -> Similar to mount(), but updates an existing mount point (if present) instead of creating a new one<br /><br /><h3>fsutils</h3><b>cp(from: String, to: String, recurse: boolean = false): boolean</b> -> Copies a file or directory, possibly across FileSystems<br /><b>head(file: String, maxBytes: int = 65536): String</b> -> Returns up to the first 'maxBytes' bytes of the given file as a String encoded in UTF-8<br /><b>ls(dir: String): Seq</b> -> Lists the contents of a directory<br /><b>mkdirs(dir: String): boolean</b> -> Creates the given directory if it does not exist, also creating any necessary parent directories<br /><b>mv(from: String, to: String, recurse: boolean = false): boolean</b> -> Moves a file or directory, possibly across FileSystems<br /><b>put(file: String, contents: String, overwrite: boolean = false): boolean</b> -> Writes the given String out to a file, encoded in UTF-8<br /><b>rm(dir: String, recurse: boolean = false): boolean</b> -> Removes a file or directory<br /><br /></div>

# %%
fsutils
cp(from: String, to: String, recurse: boolean = false): boolean -> Copia um arquivo ou diretório, possivelmente entre sistemas de arquivos
head(file: String, maxBytes: int = 65536): String -> Retorna até os primeiros bytes 'maxBytes' do arquivo fornecido como uma String codificada em UTF-8
ls(dir: String): Seq -> Lista o conteúdo de um diretório
mkdirs(dir: String): boolean -> Cria o diretório fornecido se ele não existir, criando também quaisquer diretórios pais necessários
mv(from: String, to: String, recurse: boolean = false): boolean -> Move um arquivo ou diretório, possivelmente entre sistemas de arquivos
put(arquivo: String, conteúdo: String, overwrite: boolean = false): boolean -> Grava a String fornecida em um arquivo, codificado em UTF-8
rm(dir: String, recurse: boolean = false): boolean -> Remove um arquivo ou diretório

# %%
dbutils.fs.ls('/')
# Out:
# Out[10]: [FileInfo(path='dbfs:/FileStore/', name='FileStore/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/', name='databricks-datasets/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-results/', name='databricks-results/', size=0, modificationTime=0)]

# %%
display(dbutils.fs.ls('/FileStore/tables'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/Bike Store/</td><td>Bike Store/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/Clientes.csv</td><td>Clientes.csv</td><td>12356</td><td>1742845334000</td></tr></tbody></table></div>

# %%
dbutils.fs.head('/FileStore/tables/Clientes.csv')
# Out:
# Out[12]: '\ufeffid,created_at,first_name,last_name,email,cell_phone,country,state,street,number,additionals\r\n0,2017-11-01 14:45:41,Marta,Jesus,,9 9102-7834,Brasil,Acre,,,Conjunto 16\r\n1,2017-10-16 00:50:39,Luana,Almeida,,9 7328-8718,Brasil,Rio Grande do Sul,Avenida 56 do Estado Rio Grande do Sul,989.0,Conjunto 17\r\n2,2018-06-16 17:51:29,Frida,Mendes,frida@meu_email.com,9 5906-7552,Brasil,São Paulo,Avenida 59 do Estado São Paulo,534.0,\r\n3,2018-01-17 03:02:58,Daniela,Avelino,daniela@exemplo.com,9 4642-9486,Brasil,Mato Grosso,,,\r\n4,2018-08-06 07:24:16,Romário,Teixeira,,9 3093-6522,Brasil,Bahia,Praça 56 do Estado Bahia,191.0,Apto 12\r\n5,2018-01-05 17:20:49,Marcelo,Barroso,,9 2830-2088,Brasil,Rio Grande do Sul,Rua 28 do Estado Rio Grande do Sul,805.0,Conjunto 13\r\n6,2018-06-18 11:17:42,Cristiano,Elísio,cristiano@exemplo.com,9 3532-8404,Brasil,Goiás,Rua 78 do Estado Goiás,877.0,Apto 14\r\n7,2018-02-08 12:36:09,Everton,Barbosa,everton@meu_email.com,9 2553-4087,Brasil,Distrito Federal,Avenida 86 do Estado Distrito Federal,864.0,Apto 14\r\n8,2017-12-16 20:47:03,Gabriela,Alves,gabriela@exemplo.com,9 1353-8433,Brasil,Santa Catarina,,,\r\n9,2018-11-11 11:48:41,Luan,Dias,luan@exemplo.com,9 2417-3678,Brasil,Distrito Federal,Avenida 54 do Estado Distrito Federal,889.0,Conjunto 14\r\n10,2017-12-16 15:41:00,Mariana,Alves,mariana@meu_email.com,9 1846-6377,Brasil,Santa Catarina,,,\r\n11,2018-05-16 03:39:52,James,Albuquerque,,9 2430-5905,Brasil,Sergipe,Rua 30 do Estado Sergipe,229.0,\r\n12,2018-03-28 00:24:00,Carol,Barboza,carol@exemplo.com,9 8487-3501,Brasil,Mato Grosso,Rua 31 do Estado Mato Grosso,1.0,Conjunto 23\r\n13,2018-08-27 21:15:17,Carolina,Monteiro,carolina@teste.com,9 1226-4267,Brasil,Rio Grande do Sul,Rua 4 do Estado Rio Grande do Sul,444.0,Apto 21\r\n14,2017-11-12 03:02:41,Francisco,Nascimento,francisco@exemplo.com,9 7264-9020,Brasil,Distrito Federal,Rua 75 do Estado Distrito Federal,47.0,\r\n15,2018-11-15 18:00:53,Stephanie,Barbosa,stephanie@usuario.com,9 1446-3560,Brasil,Mato Grosso,,,Conjunto 4\r\n16,2017-12-12 21:29:54,Laura,Santos,laura@exemplo.com,9 7802-6152,Brasil,Maranhão,Rua 57 do Estado Maranhão,213.0,\r\n17,2017-10-19 20:18:14,João,Magalhães,joão@exemplo.com,9 5995-1272,Brasil,Pernambuco,Rua 20 do Estado Pernambuco,781.0,Apto 17\r\n18,2018-06-28 04:53:52,Jair,Magalhães,jair@exemplo.com,9 8368-1315,Brasil,Alagoas,Avenida 74 do Estado Alagoas,118.0,Conjunto 8\r\n19,2018-10-20 19:31:52,Caíque,Monteiro,caíque@exemplo.com,9 9793-9986,Brasil,Piauí,,,Conjunto 13\r\n20,2017-12-22 10:51:28,Adalberto,Silva,adalberto@usuario.com,9 1338-1447,Brasil,São Paulo,Rua 57 do Estado São Paulo,851.0,Conjunto 20\r\n21,2018-02-21 15:35:55,Diego,Freire,diego@teste.com,9 6686-4094,Brasil,Bahia,Praça 4 do Estado Bahia,906.0,Apto 20\r\n22,2018-04-18 22:43:29,Heitor,Pereira,,9 4839-8118,Brasil,Maranhão,Avenida 84 do Estado Maranhão,948.0,\r\n23,2017-10-26 00:35:22,Maria,Pires,,9 8229-1067,Brasil,Amazonas,Avenida 80 do Estado Amazonas,581.0,\r\n24,2018-07-25 09:34:12,Jair,Barroso,jair@teste.com,9 6679-6120,Brasil,Ceará,Rua 86 do Estado Ceará,770.0,Apto 21\r\n25,2018-08-07 12:22:40,Alice,Veloso,alice@exemplo.com,9 9869-3706,Brasil,Minas Gerais,Praça 73 do Estado Minas Gerais,571.0,\r\n26,2018-12-12 11:56:14,Eloá,da Silva,eloá@usuario.com,9 3982-5948,Brasil,Espírito Santo,Avenida 98 do Estado Espírito Santo,706.0,\r\n27,2018-11-08 11:12:47,Luan,Lima,luan@teste.com,9 2529-8197,Brasil,Acre,Praça 86 do Estado Acre,303.0,Apto 27\r\n28,2017-11-26 05:17:39,Beatriz,Araújo,beatriz@usuario.com,9 4543-3853,Brasil,Minas Gerais,Praça 7 do Estado Minas Gerais,536.0,Conjunto 5\r\n29,2018-06-03 17:08:52,Geisa,Santos,geisa@meu_email.com,9 4653-9739,Brasil,Rio Grande do Norte,Avenida 77 do Estado Rio Grande do Norte,486.0,Conjunto 13\r\n30,2018-06-08 07:49:50,Gabriel,Teixeira,gabriel@exemplo.com,9 7419-5325,Brasil,Rio Grande do Sul,Avenida 7 do Estado Rio Grande do Sul,94.0,\r\n31,2018-07-02 22:04:08,Geisa,Freitas,geisa@exemplo.com,9 6772-5310,Brasil,Mato Gro ...

# %%
# inserir varios dados em pasta errada como ajustar 
display(dbutils.fs.ls('/FileStore/'))
# Out:
# Out[14]: [FileInfo(path='dbfs:/FileStore/tables/01_Primeiros_comandos.ipynb', name='01_Primeiros_comandos.ipynb', size=38361, modificationTime=1742842478000)]

# %%
dbutils.fs.rm('dbfs:/FileStore/tables/stores.csv')
# Out:
# Out[39]: True

# %%
dbutils.fs.rm('dbfs:/FileStore/tables/Bike Store/')

# %%
# Criando uma lista e deletando arquivos
# Lista de caminhos de arquivo a serem excluídos
excluir = [
    "/FileStore/categories.csv",
    "/FileStore/customers.csv",
    "/FileStore/order_items.csv",
    "/FileStore/orders.csv",
    "/FileStore/products.csv",
    "/FileStore/staffs.csv",
    "/FileStore/stocks.csv",
    "/FileStore/stores.csv",
]

# for (passar por todos arquivos)  e excluir
for apagar_arquivos in excluir:
    dbutils.fs.rm(apagar_arquivos)

# %%
#Verificando tabelas Para criar novas pastas
display(dbutils.fs.ls('/FileStore/tables'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/Bike Store/</td><td>Bike Store/</td><td>0</td><td>0</td></tr><tr><td>dbfs:/FileStore/tables/Clientes.csv</td><td>Clientes.csv</td><td>12356</td><td>1742845334000</td></tr></tbody></table></div>

# %%
#criando nova pasta 
dbutils.fs.mkdirs('/FileStore/tables/Bikes')
# Out:
# Out[54]: True

# %%
display(dbutils.fs.ls('/FileStore/tables/Bikes'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/Bikes/brands.csv</td><td>brands.csv</td><td>120</td><td>1742847267000</td></tr><tr><td>dbfs:/FileStore/tables/Bikes/categories.csv</td><td>categories.csv</td><td>162</td><td>1742847265000</td></tr><tr><td>dbfs:/FileStore/tables/Bikes/customers.csv</td><td>customers.csv</td><td>127671</td><td>1742847265000</td></tr><tr><td>dbfs:/FileStore/tables/Bikes/order_items.csv</td><td>order_items.csv</td><td>112937</td><td>1742847265000</td></tr><tr><td>dbfs:/FileStore/tables/Bikes/orders.csv</td><td>orders.csv</td><td>77286</td><td>1742847265000</td></tr><tr><td>dbfs:/FileStore/tables/Bikes/products.csv</td><td>products.csv</td><td>17390</td><td>1742847266000</td></tr><tr><td>dbfs:/FileStore/tables/Bikes/staffs.csv</td><td>staffs.csv</td><td>726</td><td>1742847266000</td></tr><tr><td>dbfs:/FileStore/tables/Bikes/stocks.csv</td><td>stocks.csv</td><td>8773</td><td>1742847266000</td></tr><tr><td>dbfs:/FileStore/tables/Bikes/stores.csv</td><td>stores.csv</td><td>330</td><td>1742847266000</td></tr></tbody></table></div>

# %% [markdown]
# ##### Visualizando os dados

# %%
dbfs:/FileStore/tables/Bikes/customers.csv
/dbfs/FileStore/tables/Bikes/customers.csv

# %%
# Ler o arquivo CSV e criar um DataFrame
spark.read.csv("/FileStore/tables/Bikes/customers.csv", header=True, inferSchema=True)
# Out:
# Out[57]: DataFrame[customer_id: int, first_name: string, last_name: string, phone: string, email: string, street: string, city: string, state: string, zip_code: int]

# %%
display(spark.read.csv("/FileStore/tables/Bikes/customers.csv", header=True, inferSchema=True))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>first_name</th><th>last_name</th><th>phone</th><th>email</th><th>street</th><th>city</th><th>state</th><th>zip_code</th></tr></thead><tbody><tr><td>1</td><td>Debra</td><td>Burks</td><td>NULL</td><td>debra.burks@yahoo.com</td><td>9273 Thorne Ave. </td><td>Orchard Park</td><td>NY</td><td>14127</td></tr><tr><td>2</td><td>Kasha</td><td>Todd</td><td>NULL</td><td>kasha.todd@yahoo.com</td><td>910 Vine Street </td><td>Campbell</td><td>CA</td><td>95008</td></tr><tr><td>3</td><td>Tameka</td><td>Fisher</td><td>NULL</td><td>tameka.fisher@aol.com</td><td>769C Honey Creek St. </td><td>Redondo Beach</td><td>CA</td><td>90278</td></tr><tr><td>4</td><td>Daryl</td><td>Spence</td><td>NULL</td><td>daryl.spence@aol.com</td><td>988 Pearl Lane </td><td>Uniondale</td><td>NY</td><td>11553</td></tr><tr><td>5</td><td>Charolette</td><td>Rice</td><td>(916) 381-6003</td><td>charolette.rice@msn.com</td><td>107 River Dr. </td><td>Sacramento</td><td>CA</td><td>95820</td></tr><tr><td>6</td><td>Lyndsey</td><td>Bean</td><td>NULL</td><td>lyndsey.bean@hotmail.com</td><td>769 West Road </td><td>Fairport</td><td>NY</td><td>14450</td></tr><tr><td>7</td><td>Latasha</td><td>Hays</td><td>(716) 986-3359</td><td>latasha.hays@hotmail.com</td><td>7014 Manor Station Rd. </td><td>Buffalo</td><td>NY</td><td>14215</td></tr><tr><td>8</td><td>Jacquline</td><td>Duncan</td><td>NULL</td><td>jacquline.duncan@yahoo.com</td><td>15 Brown St. </td><td>Jackson Heights</td><td>NY</td><td>11372</td></tr><tr><td>9</td><td>Genoveva</td><td>Baldwin</td><td>NULL</td><td>genoveva.baldwin@msn.com</td><td>8550 Spruce Drive </td><td>Port Washington</td><td>NY</td><td>11050</td></tr><tr><td>10</td><td>Pamelia</td><td>Newman</td><td>NULL</td><td>pamelia.newman@gmail.com</td><td>476 Chestnut Ave. </td><td>Monroe</td><td>NY</td><td>10950</td></tr><tr><td>11</td><td>Deshawn</td><td>Mendoza</td><td>NULL</td><td>deshawn.mendoza@yahoo.com</td><td>8790 Cobblestone Street </td><td>Monsey</td><td>NY</td><td>10952</td></tr><tr><td>12</td><td>Robby</td><td>Sykes</td><td>(516) 583-7761</td><td>robby.sykes@hotmail.com</td><td>486 Rock Maple Street </td><td>Hempstead</td><td>NY</td><td>11550</td></tr><tr><td>13</td><td>Lashawn</td><td>Ortiz</td><td>NULL</td><td>lashawn.ortiz@msn.com</td><td>27 Washington Rd. </td><td>Longview</td><td>TX</td><td>75604</td></tr><tr><td>14</td><td>Garry</td><td>Espinoza</td><td>NULL</td><td>garry.espinoza@hotmail.com</td><td>7858 Rockaway Court </td><td>Forney</td><td>TX</td><td>75126</td></tr><tr><td>15</td><td>Linnie</td><td>Branch</td><td>NULL</td><td>linnie.branch@gmail.com</td><td>314 South Columbia Ave. </td><td>Plattsburgh</td><td>NY</td><td>12901</td></tr><tr><td>16</td><td>Emmitt</td><td>Sanchez</td><td>(212) 945-8823</td><td>emmitt.sanchez@hotmail.com</td><td>461 Squaw Creek Road </td><td>New York</td><td>NY</td><td>10002</td></tr><tr><td>17</td><td>Caren</td><td>Stephens</td><td>NULL</td><td>caren.stephens@msn.com</td><td>914 Brook St. </td><td>Scarsdale</td><td>NY</td><td>10583</td></tr><tr><td>18</td><td>Georgetta</td><td>Hardin</td><td>NULL</td><td>georgetta.hardin@aol.com</td><td>474 Chapel Dr. </td><td>Canandaigua</td><td>NY</td><td>14424</td></tr><tr><td>19</td><td>Lizzette</td><td>Stein</td><td>NULL</td><td>lizzette.stein@yahoo.com</td><td>19 Green Hill Lane </td><td>Orchard Park</td><td>NY</td><td>14127</td></tr><tr><td>20</td><td>Aleta</td><td>Shepard</td><td>NULL</td><td>aleta.shepard@aol.com</td><td>684 Howard St. </td><td>Sugar Land</td><td>TX</td><td>77478</td></tr><tr><td>21</td><td>Tobie</td><td>Little</td><td>NULL</td><td>tobie.little@gmail.com</td><td>10 Silver Spear Dr. </td><td>Victoria</td><td>TX</td><td>77904</td></tr><tr><td>22</td><td>Adelle</td><td>Larsen</td><td>NULL</td><td>adelle.larsen@gmail.com</td><td>683 West Kirkland Dr. </td><td>East Northport</td><td>NY</td><td>11731</td></tr><tr><td>23</td><td>Kaylee</t ...

# %%
display(spark.read.csv("dbfs:/FileStore/tables/Bikes/customers.csv", header=True, inferSchema=True))
#header = primeira linha é o cabeçalho?
#inferSchema = inserir automaticamente os tipos de dados(numero,texto,data etc....)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>first_name</th><th>last_name</th><th>phone</th><th>email</th><th>street</th><th>city</th><th>state</th><th>zip_code</th></tr></thead><tbody><tr><td>1</td><td>Debra</td><td>Burks</td><td>NULL</td><td>debra.burks@yahoo.com</td><td>9273 Thorne Ave. </td><td>Orchard Park</td><td>NY</td><td>14127</td></tr><tr><td>2</td><td>Kasha</td><td>Todd</td><td>NULL</td><td>kasha.todd@yahoo.com</td><td>910 Vine Street </td><td>Campbell</td><td>CA</td><td>95008</td></tr><tr><td>3</td><td>Tameka</td><td>Fisher</td><td>NULL</td><td>tameka.fisher@aol.com</td><td>769C Honey Creek St. </td><td>Redondo Beach</td><td>CA</td><td>90278</td></tr><tr><td>4</td><td>Daryl</td><td>Spence</td><td>NULL</td><td>daryl.spence@aol.com</td><td>988 Pearl Lane </td><td>Uniondale</td><td>NY</td><td>11553</td></tr><tr><td>5</td><td>Charolette</td><td>Rice</td><td>(916) 381-6003</td><td>charolette.rice@msn.com</td><td>107 River Dr. </td><td>Sacramento</td><td>CA</td><td>95820</td></tr><tr><td>6</td><td>Lyndsey</td><td>Bean</td><td>NULL</td><td>lyndsey.bean@hotmail.com</td><td>769 West Road </td><td>Fairport</td><td>NY</td><td>14450</td></tr><tr><td>7</td><td>Latasha</td><td>Hays</td><td>(716) 986-3359</td><td>latasha.hays@hotmail.com</td><td>7014 Manor Station Rd. </td><td>Buffalo</td><td>NY</td><td>14215</td></tr><tr><td>8</td><td>Jacquline</td><td>Duncan</td><td>NULL</td><td>jacquline.duncan@yahoo.com</td><td>15 Brown St. </td><td>Jackson Heights</td><td>NY</td><td>11372</td></tr><tr><td>9</td><td>Genoveva</td><td>Baldwin</td><td>NULL</td><td>genoveva.baldwin@msn.com</td><td>8550 Spruce Drive </td><td>Port Washington</td><td>NY</td><td>11050</td></tr><tr><td>10</td><td>Pamelia</td><td>Newman</td><td>NULL</td><td>pamelia.newman@gmail.com</td><td>476 Chestnut Ave. </td><td>Monroe</td><td>NY</td><td>10950</td></tr><tr><td>11</td><td>Deshawn</td><td>Mendoza</td><td>NULL</td><td>deshawn.mendoza@yahoo.com</td><td>8790 Cobblestone Street </td><td>Monsey</td><td>NY</td><td>10952</td></tr><tr><td>12</td><td>Robby</td><td>Sykes</td><td>(516) 583-7761</td><td>robby.sykes@hotmail.com</td><td>486 Rock Maple Street </td><td>Hempstead</td><td>NY</td><td>11550</td></tr><tr><td>13</td><td>Lashawn</td><td>Ortiz</td><td>NULL</td><td>lashawn.ortiz@msn.com</td><td>27 Washington Rd. </td><td>Longview</td><td>TX</td><td>75604</td></tr><tr><td>14</td><td>Garry</td><td>Espinoza</td><td>NULL</td><td>garry.espinoza@hotmail.com</td><td>7858 Rockaway Court </td><td>Forney</td><td>TX</td><td>75126</td></tr><tr><td>15</td><td>Linnie</td><td>Branch</td><td>NULL</td><td>linnie.branch@gmail.com</td><td>314 South Columbia Ave. </td><td>Plattsburgh</td><td>NY</td><td>12901</td></tr><tr><td>16</td><td>Emmitt</td><td>Sanchez</td><td>(212) 945-8823</td><td>emmitt.sanchez@hotmail.com</td><td>461 Squaw Creek Road </td><td>New York</td><td>NY</td><td>10002</td></tr><tr><td>17</td><td>Caren</td><td>Stephens</td><td>NULL</td><td>caren.stephens@msn.com</td><td>914 Brook St. </td><td>Scarsdale</td><td>NY</td><td>10583</td></tr><tr><td>18</td><td>Georgetta</td><td>Hardin</td><td>NULL</td><td>georgetta.hardin@aol.com</td><td>474 Chapel Dr. </td><td>Canandaigua</td><td>NY</td><td>14424</td></tr><tr><td>19</td><td>Lizzette</td><td>Stein</td><td>NULL</td><td>lizzette.stein@yahoo.com</td><td>19 Green Hill Lane </td><td>Orchard Park</td><td>NY</td><td>14127</td></tr><tr><td>20</td><td>Aleta</td><td>Shepard</td><td>NULL</td><td>aleta.shepard@aol.com</td><td>684 Howard St. </td><td>Sugar Land</td><td>TX</td><td>77478</td></tr><tr><td>21</td><td>Tobie</td><td>Little</td><td>NULL</td><td>tobie.little@gmail.com</td><td>10 Silver Spear Dr. </td><td>Victoria</td><td>TX</td><td>77904</td></tr><tr><td>22</td><td>Adelle</td><td>Larsen</td><td>NULL</td><td>adelle.larsen@gmail.com</td><td>683 West Kirkland Dr. </td><td>East Northport</td><td>NY</td><td>11731</td></tr><tr><td>23</td><td>Kaylee</t ...

# %%
#salvando dados em um DF(DataFlame)
df = spark.read.csv("dbfs:/FileStore/tables/Bikes/customers.csv", header=True, inferSchema=True)

# %% [markdown]
# #####Tipos de visualizações

# %%
df
# Out:
# Out[61]: DataFrame[customer_id: int, first_name: string, last_name: string, phone: string, email: string, street: string, city: string, state: string, zip_code: int]

# %%
df.show()
# Out:
# +-----------+----------+---------+--------------+--------------------+--------------------+---------------+-----+--------+
# |customer_id|first_name|last_name|         phone|               email|              street|           city|state|zip_code|
# +-----------+----------+---------+--------------+--------------------+--------------------+---------------+-----+--------+
# |          1|     Debra|    Burks|          NULL|debra.burks@yahoo...|   9273 Thorne Ave. |   Orchard Park|   NY|   14127|
# |          2|     Kasha|     Todd|          NULL|kasha.todd@yahoo.com|    910 Vine Street |       Campbell|   CA|   95008|
# |          3|    Tameka|   Fisher|          NULL|tameka.fisher@aol...|769C Honey Creek ...|  Redondo Beach|   CA|   90278|
# |          4|     Daryl|   Spence|          NULL|daryl.spence@aol.com|     988 Pearl Lane |      Uniondale|   NY|   11553|
# |          5|Charolette|     Rice|(916) 381-6003|charolette.rice@m...|      107 River Dr. |     Sacramento|   CA|   95820|
# |          6|   Lyndsey|     Bean|          NULL|lyndsey.bean@hotm...|      769 West Road |       Fairport|   NY|   14450|
# |          7|   Latasha|     Hays|(716) 986-3359|latasha.hays@hotm...|7014 Manor Statio...|        Buffalo|   NY|   14215|
# |          8| Jacquline|   Duncan|          NULL|jacquline.duncan@...|       15 Brown St. |Jackson Heights|   NY|   11372|
# |          9|  Genoveva|  Baldwin|          NULL|genoveva.baldwin@...|  8550 Spruce Drive |Port Washington|   NY|   11050|
# |         10|   Pamelia|   Newman|          NULL|pamelia.newman@gm...|  476 Chestnut Ave. |         Monroe|   NY|   10950|
# |         11|   Deshawn|  Mendoza|          NULL|deshawn.mendoza@y...|8790 Cobblestone ...|         Monsey|   NY|   10952|
# |         12|     Robby|    Sykes|(516) 583-7761|robby.sykes@hotma...|486 Rock Maple St...|      Hempstead|   NY|   11550|
# |         13|   Lashawn|    Ortiz|          NULL|lashawn.ortiz@msn...|  27 Washington Rd. |       Longview|   TX|   75604|
# |         14|     Garry| Espinoza|          NULL|garry.espinoza@ho...|7858 Rockaway Court |         Forney|   TX|   75126|
# |         15|    Linnie|   Branch|          NULL|linnie.branch@gma...|314 South Columbi...|    Plattsburgh|   NY|   12901|
# |         16|    Emmitt|  Sanchez|(212) 945-8823|emmitt.sanchez@ho...|461 Squaw Creek R...|       New York|   NY|   10002|
# |         17|     Caren| Stephens|          NULL|caren.stephens@ms...|      914 Brook St. |      Scarsdale|   NY|   10583|
# |         18| Georgetta|   Hardin|          NULL|georgetta.hardin@...|     474 Chapel Dr. |    Canandaigua|   NY|   14424|
# |         19|  Lizzette|    Stein|          NULL|lizzette.stein@ya...| 19 Green Hill Lane |   Orchard Park|   NY|   14127|
# |         20|     Aleta|  Shepard|          NULL|aleta.shepard@aol...|     684 Howard St. |     Sugar Land|   TX|   77478|
# +-----------+----------+---------+--------------+--------------------+--------------------+---------------+-----+--------+
# only showing top 20 rows

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>first_name</th><th>last_name</th><th>phone</th><th>email</th><th>street</th><th>city</th><th>state</th><th>zip_code</th></tr></thead><tbody><tr><td>1</td><td>Debra</td><td>Burks</td><td>NULL</td><td>debra.burks@yahoo.com</td><td>9273 Thorne Ave. </td><td>Orchard Park</td><td>NY</td><td>14127</td></tr><tr><td>2</td><td>Kasha</td><td>Todd</td><td>NULL</td><td>kasha.todd@yahoo.com</td><td>910 Vine Street </td><td>Campbell</td><td>CA</td><td>95008</td></tr><tr><td>3</td><td>Tameka</td><td>Fisher</td><td>NULL</td><td>tameka.fisher@aol.com</td><td>769C Honey Creek St. </td><td>Redondo Beach</td><td>CA</td><td>90278</td></tr><tr><td>4</td><td>Daryl</td><td>Spence</td><td>NULL</td><td>daryl.spence@aol.com</td><td>988 Pearl Lane </td><td>Uniondale</td><td>NY</td><td>11553</td></tr><tr><td>5</td><td>Charolette</td><td>Rice</td><td>(916) 381-6003</td><td>charolette.rice@msn.com</td><td>107 River Dr. </td><td>Sacramento</td><td>CA</td><td>95820</td></tr><tr><td>6</td><td>Lyndsey</td><td>Bean</td><td>NULL</td><td>lyndsey.bean@hotmail.com</td><td>769 West Road </td><td>Fairport</td><td>NY</td><td>14450</td></tr><tr><td>7</td><td>Latasha</td><td>Hays</td><td>(716) 986-3359</td><td>latasha.hays@hotmail.com</td><td>7014 Manor Station Rd. </td><td>Buffalo</td><td>NY</td><td>14215</td></tr><tr><td>8</td><td>Jacquline</td><td>Duncan</td><td>NULL</td><td>jacquline.duncan@yahoo.com</td><td>15 Brown St. </td><td>Jackson Heights</td><td>NY</td><td>11372</td></tr><tr><td>9</td><td>Genoveva</td><td>Baldwin</td><td>NULL</td><td>genoveva.baldwin@msn.com</td><td>8550 Spruce Drive </td><td>Port Washington</td><td>NY</td><td>11050</td></tr><tr><td>10</td><td>Pamelia</td><td>Newman</td><td>NULL</td><td>pamelia.newman@gmail.com</td><td>476 Chestnut Ave. </td><td>Monroe</td><td>NY</td><td>10950</td></tr><tr><td>11</td><td>Deshawn</td><td>Mendoza</td><td>NULL</td><td>deshawn.mendoza@yahoo.com</td><td>8790 Cobblestone Street </td><td>Monsey</td><td>NY</td><td>10952</td></tr><tr><td>12</td><td>Robby</td><td>Sykes</td><td>(516) 583-7761</td><td>robby.sykes@hotmail.com</td><td>486 Rock Maple Street </td><td>Hempstead</td><td>NY</td><td>11550</td></tr><tr><td>13</td><td>Lashawn</td><td>Ortiz</td><td>NULL</td><td>lashawn.ortiz@msn.com</td><td>27 Washington Rd. </td><td>Longview</td><td>TX</td><td>75604</td></tr><tr><td>14</td><td>Garry</td><td>Espinoza</td><td>NULL</td><td>garry.espinoza@hotmail.com</td><td>7858 Rockaway Court </td><td>Forney</td><td>TX</td><td>75126</td></tr><tr><td>15</td><td>Linnie</td><td>Branch</td><td>NULL</td><td>linnie.branch@gmail.com</td><td>314 South Columbia Ave. </td><td>Plattsburgh</td><td>NY</td><td>12901</td></tr><tr><td>16</td><td>Emmitt</td><td>Sanchez</td><td>(212) 945-8823</td><td>emmitt.sanchez@hotmail.com</td><td>461 Squaw Creek Road </td><td>New York</td><td>NY</td><td>10002</td></tr><tr><td>17</td><td>Caren</td><td>Stephens</td><td>NULL</td><td>caren.stephens@msn.com</td><td>914 Brook St. </td><td>Scarsdale</td><td>NY</td><td>10583</td></tr><tr><td>18</td><td>Georgetta</td><td>Hardin</td><td>NULL</td><td>georgetta.hardin@aol.com</td><td>474 Chapel Dr. </td><td>Canandaigua</td><td>NY</td><td>14424</td></tr><tr><td>19</td><td>Lizzette</td><td>Stein</td><td>NULL</td><td>lizzette.stein@yahoo.com</td><td>19 Green Hill Lane </td><td>Orchard Park</td><td>NY</td><td>14127</td></tr><tr><td>20</td><td>Aleta</td><td>Shepard</td><td>NULL</td><td>aleta.shepard@aol.com</td><td>684 Howard St. </td><td>Sugar Land</td><td>TX</td><td>77478</td></tr><tr><td>21</td><td>Tobie</td><td>Little</td><td>NULL</td><td>tobie.little@gmail.com</td><td>10 Silver Spear Dr. </td><td>Victoria</td><td>TX</td><td>77904</td></tr><tr><td>22</td><td>Adelle</td><td>Larsen</td><td>NULL</td><td>adelle.larsen@gmail.com</td><td>683 West Kirkland Dr. </td><td>East Northport</td><td>NY</td><td>11731</td></tr><tr><td>23</td><td>Kaylee</t ...

# %%
#Ver algumas colunas sem salvar em um DF
colunas = ["customer_id", "first_name", "email", "state"]
display(df.select(colunas))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>first_name</th><th>email</th><th>state</th></tr></thead><tbody><tr><td>1</td><td>Debra</td><td>debra.burks@yahoo.com</td><td>NY</td></tr><tr><td>2</td><td>Kasha</td><td>kasha.todd@yahoo.com</td><td>CA</td></tr><tr><td>3</td><td>Tameka</td><td>tameka.fisher@aol.com</td><td>CA</td></tr><tr><td>4</td><td>Daryl</td><td>daryl.spence@aol.com</td><td>NY</td></tr><tr><td>5</td><td>Charolette</td><td>charolette.rice@msn.com</td><td>CA</td></tr><tr><td>6</td><td>Lyndsey</td><td>lyndsey.bean@hotmail.com</td><td>NY</td></tr><tr><td>7</td><td>Latasha</td><td>latasha.hays@hotmail.com</td><td>NY</td></tr><tr><td>8</td><td>Jacquline</td><td>jacquline.duncan@yahoo.com</td><td>NY</td></tr><tr><td>9</td><td>Genoveva</td><td>genoveva.baldwin@msn.com</td><td>NY</td></tr><tr><td>10</td><td>Pamelia</td><td>pamelia.newman@gmail.com</td><td>NY</td></tr><tr><td>11</td><td>Deshawn</td><td>deshawn.mendoza@yahoo.com</td><td>NY</td></tr><tr><td>12</td><td>Robby</td><td>robby.sykes@hotmail.com</td><td>NY</td></tr><tr><td>13</td><td>Lashawn</td><td>lashawn.ortiz@msn.com</td><td>TX</td></tr><tr><td>14</td><td>Garry</td><td>garry.espinoza@hotmail.com</td><td>TX</td></tr><tr><td>15</td><td>Linnie</td><td>linnie.branch@gmail.com</td><td>NY</td></tr><tr><td>16</td><td>Emmitt</td><td>emmitt.sanchez@hotmail.com</td><td>NY</td></tr><tr><td>17</td><td>Caren</td><td>caren.stephens@msn.com</td><td>NY</td></tr><tr><td>18</td><td>Georgetta</td><td>georgetta.hardin@aol.com</td><td>NY</td></tr><tr><td>19</td><td>Lizzette</td><td>lizzette.stein@yahoo.com</td><td>NY</td></tr><tr><td>20</td><td>Aleta</td><td>aleta.shepard@aol.com</td><td>TX</td></tr><tr><td>21</td><td>Tobie</td><td>tobie.little@gmail.com</td><td>TX</td></tr><tr><td>22</td><td>Adelle</td><td>adelle.larsen@gmail.com</td><td>NY</td></tr><tr><td>23</td><td>Kaylee</td><td>kaylee.english@msn.com</td><td>NY</td></tr><tr><td>24</td><td>Corene</td><td>corene.wall@msn.com</td><td>CA</td></tr><tr><td>25</td><td>Regenia</td><td>regenia.vaughan@gmail.com</td><td>NY</td></tr><tr><td>26</td><td>Theo</td><td>theo.reese@gmail.com</td><td>NY</td></tr><tr><td>27</td><td>Santos</td><td>santos.valencia@yahoo.com</td><td>NY</td></tr><tr><td>28</td><td>Jeanice</td><td>jeanice.frost@hotmail.com</td><td>NY</td></tr><tr><td>29</td><td>Syreeta</td><td>syreeta.hendricks@msn.com</td><td>NY</td></tr><tr><td>30</td><td>Jamaal</td><td>jamaal.albert@gmail.com</td><td>CA</td></tr><tr><td>31</td><td>Williemae</td><td>williemae.holloway@msn.com</td><td>CA</td></tr><tr><td>32</td><td>Araceli</td><td>araceli.golden@msn.com</td><td>CA</td></tr><tr><td>33</td><td>Deloris</td><td>deloris.burke@hotmail.com</td><td>CA</td></tr><tr><td>34</td><td>Brittney</td><td>brittney.woodward@aol.com</td><td>NY</td></tr><tr><td>35</td><td>Guillermina</td><td>guillermina.noble@msn.com</td><td>NY</td></tr><tr><td>36</td><td>Bernita</td><td>bernita.mcdaniel@hotmail.com</td><td>NY</td></tr><tr><td>37</td><td>Melia</td><td>melia.brady@gmail.com</td><td>NY</td></tr><tr><td>38</td><td>Zelma</td><td>zelma.browning@aol.com</td><td>NY</td></tr><tr><td>39</td><td>Janetta</td><td>janetta.aguirre@aol.com</td><td>NY</td></tr><tr><td>40</td><td>Ronna</td><td>ronna.butler@gmail.com</td><td>CA</td></tr><tr><td>41</td><td>Kathie</td><td>kathie.freeman@msn.com</td><td>NY</td></tr><tr><td>42</td><td>Tangela</td><td>tangela.quinn@aol.com</td><td>NY</td></tr><tr><td>43</td><td>Mozelle</td><td>mozelle.carter@aol.com</td><td>TX</td></tr><tr><td>44</td><td>Onita</td><td>onita.johns@msn.com</td><td>NY</td></tr><tr><td>45</td><td>Bennett</td><td>bennett.armstrong@aol.com</td><td>NY</td></tr><tr><td>46</td><td>Monika</td><td>monika.berg@gmail.com</td><td>CA</td></tr><tr><td>47</td><td>Bridgette</td><td>bridgette.guerra@hotmail.com</td><td>CA</td></tr><tr><td>48</td><td>Cesar</td><td>cesar.jackson@gmail.com</td><td>NY</td></tr><tr><td>49</td><td>Caroll</td ...

# %%
df.select('customer_id','email').show()
# Out:
# +-----------+--------------------+
# |customer_id|               email|
# +-----------+--------------------+
# |          1|debra.burks@yahoo...|
# |          2|kasha.todd@yahoo.com|
# |          3|tameka.fisher@aol...|
# |          4|daryl.spence@aol.com|
# |          5|charolette.rice@m...|
# |          6|lyndsey.bean@hotm...|
# |          7|latasha.hays@hotm...|
# |          8|jacquline.duncan@...|
# |          9|genoveva.baldwin@...|
# |         10|pamelia.newman@gm...|
# |         11|deshawn.mendoza@y...|
# |         12|robby.sykes@hotma...|
# |         13|lashawn.ortiz@msn...|
# |         14|garry.espinoza@ho...|
# |         15|linnie.branch@gma...|
# |         16|emmitt.sanchez@ho...|
# |         17|caren.stephens@ms...|
# |         18|georgetta.hardin@...|
# |         19|lizzette.stein@ya...|
# |         20|aleta.shepard@aol...|
# +-----------+--------------------+
# only showing top 20 rows

# %%
display(df.select('customer_id','email'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>email</th></tr></thead><tbody><tr><td>1</td><td>debra.burks@yahoo.com</td></tr><tr><td>2</td><td>kasha.todd@yahoo.com</td></tr><tr><td>3</td><td>tameka.fisher@aol.com</td></tr><tr><td>4</td><td>daryl.spence@aol.com</td></tr><tr><td>5</td><td>charolette.rice@msn.com</td></tr><tr><td>6</td><td>lyndsey.bean@hotmail.com</td></tr><tr><td>7</td><td>latasha.hays@hotmail.com</td></tr><tr><td>8</td><td>jacquline.duncan@yahoo.com</td></tr><tr><td>9</td><td>genoveva.baldwin@msn.com</td></tr><tr><td>10</td><td>pamelia.newman@gmail.com</td></tr><tr><td>11</td><td>deshawn.mendoza@yahoo.com</td></tr><tr><td>12</td><td>robby.sykes@hotmail.com</td></tr><tr><td>13</td><td>lashawn.ortiz@msn.com</td></tr><tr><td>14</td><td>garry.espinoza@hotmail.com</td></tr><tr><td>15</td><td>linnie.branch@gmail.com</td></tr><tr><td>16</td><td>emmitt.sanchez@hotmail.com</td></tr><tr><td>17</td><td>caren.stephens@msn.com</td></tr><tr><td>18</td><td>georgetta.hardin@aol.com</td></tr><tr><td>19</td><td>lizzette.stein@yahoo.com</td></tr><tr><td>20</td><td>aleta.shepard@aol.com</td></tr><tr><td>21</td><td>tobie.little@gmail.com</td></tr><tr><td>22</td><td>adelle.larsen@gmail.com</td></tr><tr><td>23</td><td>kaylee.english@msn.com</td></tr><tr><td>24</td><td>corene.wall@msn.com</td></tr><tr><td>25</td><td>regenia.vaughan@gmail.com</td></tr><tr><td>26</td><td>theo.reese@gmail.com</td></tr><tr><td>27</td><td>santos.valencia@yahoo.com</td></tr><tr><td>28</td><td>jeanice.frost@hotmail.com</td></tr><tr><td>29</td><td>syreeta.hendricks@msn.com</td></tr><tr><td>30</td><td>jamaal.albert@gmail.com</td></tr><tr><td>31</td><td>williemae.holloway@msn.com</td></tr><tr><td>32</td><td>araceli.golden@msn.com</td></tr><tr><td>33</td><td>deloris.burke@hotmail.com</td></tr><tr><td>34</td><td>brittney.woodward@aol.com</td></tr><tr><td>35</td><td>guillermina.noble@msn.com</td></tr><tr><td>36</td><td>bernita.mcdaniel@hotmail.com</td></tr><tr><td>37</td><td>melia.brady@gmail.com</td></tr><tr><td>38</td><td>zelma.browning@aol.com</td></tr><tr><td>39</td><td>janetta.aguirre@aol.com</td></tr><tr><td>40</td><td>ronna.butler@gmail.com</td></tr><tr><td>41</td><td>kathie.freeman@msn.com</td></tr><tr><td>42</td><td>tangela.quinn@aol.com</td></tr><tr><td>43</td><td>mozelle.carter@aol.com</td></tr><tr><td>44</td><td>onita.johns@msn.com</td></tr><tr><td>45</td><td>bennett.armstrong@aol.com</td></tr><tr><td>46</td><td>monika.berg@gmail.com</td></tr><tr><td>47</td><td>bridgette.guerra@hotmail.com</td></tr><tr><td>48</td><td>cesar.jackson@gmail.com</td></tr><tr><td>49</td><td>caroll.hays@yahoo.com</td></tr><tr><td>50</td><td>cleotilde.booth@gmail.com</td></tr><tr><td>51</td><td>gertrud.rhodes@aol.com</td></tr><tr><td>52</td><td>tu.ramirez@hotmail.com</td></tr><tr><td>53</td><td>saturnina.garner@gmail.com</td></tr><tr><td>54</td><td>fran.yang@hotmail.com</td></tr><tr><td>55</td><td>diana.guerra@hotmail.com</td></tr><tr><td>56</td><td>lolita.mosley@hotmail.com</td></tr><tr><td>57</td><td>pamala.henry@aol.com</td></tr><tr><td>58</td><td>damien.dorsey@yahoo.com</td></tr><tr><td>59</td><td>latasha.stanley@gmail.com</td></tr><tr><td>60</td><td>neil.mccall@gmail.com</td></tr><tr><td>61</td><td>elinore.aguilar@msn.com</td></tr><tr><td>62</td><td>alica.hunter@hotmail.com</td></tr><tr><td>63</td><td>tenisha.lyons@aol.com</td></tr><tr><td>64</td><td>bobbie.foster@yahoo.com</td></tr><tr><td>65</td><td>kanesha.vega@gmail.com</td></tr><tr><td>66</td><td>lorrie.becker@yahoo.com</td></tr><tr><td>67</td><td>tommie.melton@gmail.com</td></tr><tr><td>68</td><td>jayne.kirkland@hotmail.com</td></tr><tr><td>69</td><td>katelin.kennedy@gmail.com</td></tr><tr><td>70</td><td>tomasa.carson@aol.com</td></tr><tr><td>71</td><td>takako.casey@aol.com</td></tr><tr><td>72</td><td>petronila.norris@aol.com</td></tr><tr><td>73</td><td>melanie.hayes@msn.com</td></tr><tr><td>74</td><td>georgeann.waller@yahoo ...

# %%
#salvando em um novo DF ou subscrevendo
colunas = ["customer_id", "first_name", "email", "state"]
dfFiltrado = df.select(colunas)

# %%
dfFiltrado.show(5)
# Out:
# +-----------+----------+--------------------+-----+
# |customer_id|first_name|               email|state|
# +-----------+----------+--------------------+-----+
# |          1|     Debra|debra.burks@yahoo...|   NY|
# |          2|     Kasha|kasha.todd@yahoo.com|   CA|
# |          3|    Tameka|tameka.fisher@aol...|   CA|
# |          4|     Daryl|daryl.spence@aol.com|   NY|
# |          5|Charolette|charolette.rice@m...|   CA|
# +-----------+----------+--------------------+-----+
# only showing top 5 rows

# %%
df.show(5)
# Out:
# +-----------+----------+---------+--------------+--------------------+--------------------+-------------+-----+--------+
# |customer_id|first_name|last_name|         phone|               email|              street|         city|state|zip_code|
# +-----------+----------+---------+--------------+--------------------+--------------------+-------------+-----+--------+
# |          1|     Debra|    Burks|          NULL|debra.burks@yahoo...|   9273 Thorne Ave. | Orchard Park|   NY|   14127|
# |          2|     Kasha|     Todd|          NULL|kasha.todd@yahoo.com|    910 Vine Street |     Campbell|   CA|   95008|
# |          3|    Tameka|   Fisher|          NULL|tameka.fisher@aol...|769C Honey Creek ...|Redondo Beach|   CA|   90278|
# |          4|     Daryl|   Spence|          NULL|daryl.spence@aol.com|     988 Pearl Lane |    Uniondale|   NY|   11553|
# |          5|Charolette|     Rice|(916) 381-6003|charolette.rice@m...|      107 River Dr. |   Sacramento|   CA|   95820|
# +-----------+----------+---------+--------------+--------------------+--------------------+-------------+-----+--------+
# only showing top 5 rows

# %% [markdown]
# Sobrescrevendo DF

# %%
df =  df.select('first_name','email','city')

# %%
df.show(5)
# Out:
# +----------+--------------------+-------------+
# |first_name|               email|         city|
# +----------+--------------------+-------------+
# |     Debra|debra.burks@yahoo...| Orchard Park|
# |     Kasha|kasha.todd@yahoo.com|     Campbell|
# |    Tameka|tameka.fisher@aol...|Redondo Beach|
# |     Daryl|daryl.spence@aol.com|    Uniondale|
# |Charolette|charolette.rice@m...|   Sacramento|
# +----------+--------------------+-------------+
# only showing top 5 rows

# %% [markdown]
# ##### Localizando Base de Dados Para Treino
#
# https://www.kaggle.com

# %%
dbutils.fs.ls('/')
# Out:
# Out[49]: [FileInfo(path='dbfs:/FileStore/', name='FileStore/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/', name='databricks-datasets/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-results/', name='databricks-results/', size=0, modificationTime=0)]

# %%
dbutils.fs.ls('/databricks-datasets')
# Out:
# Out[50]: [FileInfo(path='dbfs:/databricks-datasets/COVID/', name='COVID/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/README.md', name='README.md', size=976, modificationTime=1532468253000),
#  FileInfo(path='dbfs:/databricks-datasets/Rdatasets/', name='Rdatasets/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/SPARK_README.md', name='SPARK_README.md', size=3359, modificationTime=1455043490000),
#  FileInfo(path='dbfs:/databricks-datasets/adult/', name='adult/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/airlines/', name='airlines/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/amazon/', name='amazon/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/asa/', name='asa/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/atlas_higgs/', name='atlas_higgs/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/bikeSharing/', name='bikeSharing/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/cctvVideos/', name='cctvVideos/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/credit-card-fraud/', name='credit-card-fraud/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/cs100/', name='cs100/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/cs110x/', name='cs110x/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/cs190/', name='cs190/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/data.gov/', name='data.gov/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/definitive-guide/', name='definitive-guide/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/delta-sharing/', name='delta-sharing/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/flights/', name='flights/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/flower_photos/', name='flower_photos/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/flowers/', name='flowers/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/genomics/', name='genomics/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/hail/', name='hail/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/identifying-campaign-effectiveness/', name='identifying-campaign-effectiveness/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/iot/', name='iot/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/iot-stream/', name='iot-stream/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/learning-spark/', name='learning-spark/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/learning-spark-v2/', name='learning-spark-v2/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/lending-club-loan-stats/', name='lending-club-loan-stats/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/med-images/', name='med-images/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/media/', name='media/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/mnist-digits/', name='mnist-digits/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/news20.binary/', name='news20.binary/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/nyctaxi/', name='nyctaxi/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/nyctaxi-with-zipcodes/', name='nyctaxi-with-zipcodes/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/online_retail/', name='online_retail/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/overlap-join/', name='overlap-join/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/power-plant/', name='power-plant/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/retail-org/', name='retail-org/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/rwe/', name='rwe/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/sai-summit-2019-sf/', name='sai-summit-2019-sf/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/sample_logs/', name='sample_logs/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/samples/', name='samples/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/sfo_customer_survey/', name='sfo_customer_survey/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/sms_spam_collection/', name='sms_spam_collection/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/songs/', name='songs/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/structured-streaming/', name='structured-streaming/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/timeseries/', name='timeseries/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/tpch/', name='tpch/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/travel_recommendations_realtime/', name='travel_recommendations_realtime/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/warmup/', name='warmup/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/weather/', name='weather/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/wiki/', name='wiki/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/wikipedia-datasets/', name='wikipedia-datasets/', size=0, modificationTime=0),
#  FileInfo(path='dbfs:/databricks-datasets/wine-quality/', name='wine-quality/', size=0, modificationTime=0)]

# %%
display(dbutils.fs.ls('/databricks-datasets/wine-quality/'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/databricks-datasets/wine-quality/README.md</td><td>README.md</td><td>1066</td><td>1594262736000</td></tr><tr><td>dbfs:/databricks-datasets/wine-quality/winequality-red.csv</td><td>winequality-red.csv</td><td>84199</td><td>1594262736000</td></tr><tr><td>dbfs:/databricks-datasets/wine-quality/winequality-white.csv</td><td>winequality-white.csv</td><td>264426</td><td>1594262736000</td></tr></tbody></table></div>

# %%
spark.read.csv('dbfs:/databricks-datasets/wine-quality/winequality-white.csv',header=True , inferSchema=True , sep=';').show(5)
# Out:
# +-------------+----------------+-----------+--------------+---------+-------------------+--------------------+-------+----+---------+-------+-------+
# |fixed acidity|volatile acidity|citric acid|residual sugar|chlorides|free sulfur dioxide|total sulfur dioxide|density|  pH|sulphates|alcohol|quality|
# +-------------+----------------+-----------+--------------+---------+-------------------+--------------------+-------+----+---------+-------+-------+
# |          7.0|            0.27|       0.36|          20.7|    0.045|               45.0|               170.0|  1.001| 3.0|     0.45|    8.8|      6|
# |          6.3|             0.3|       0.34|           1.6|    0.049|               14.0|               132.0|  0.994| 3.3|     0.49|    9.5|      6|
# |          8.1|            0.28|        0.4|           6.9|     0.05|               30.0|                97.0| 0.9951|3.26|     0.44|   10.1|      6|
# |          7.2|            0.23|       0.32|           8.5|    0.058|               47.0|               186.0| 0.9956|3.19|      0.4|    9.9|      6|
# |          7.2|            0.23|       0.32|           8.5|    0.058|               47.0|               186.0| 0.9956|3.19|      0.4|    9.9|      6|
# +-------------+----------------+-----------+--------------+---------+-------------------+--------------------+-------+----+---------+-------+-------+
# only showing top 5 rows

# %%
display(dbutils.fs.ls('/databricks-datasets/COVID/coronavirusdataset/'))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>dbfs:/databricks-datasets/COVID/coronavirusdataset/.DS_Store</td><td>.DS_Store</td><td>6148</td><td>1594102716000</td></tr><tr><td>dbfs:/databricks-datasets/COVID/coronavirusdataset/Case.csv</td><td>Case.csv</td><td>11711</td><td>1595191979000</td></tr><tr><td>dbfs:/databricks-datasets/COVID/coronavirusdataset/PatientInfo.csv</td><td>PatientInfo.csv</td><td>488859</td><td>1595191979000</td></tr><tr><td>dbfs:/databricks-datasets/COVID/coronavirusdataset/PatientRoute.csv</td><td>PatientRoute.csv</td><td>718510</td><td>1594102718000</td></tr><tr><td>dbfs:/databricks-datasets/COVID/coronavirusdataset/Policy.csv</td><td>Policy.csv</td><td>5713</td><td>1595191981000</td></tr><tr><td>dbfs:/databricks-datasets/COVID/coronavirusdataset/Region.csv</td><td>Region.csv</td><td>19082</td><td>1595191981000</td></tr><tr><td>dbfs:/databricks-datasets/COVID/coronavirusdataset/SearchTrend.csv</td><td>SearchTrend.csv</td><td>71722</td><td>1595191981000</td></tr><tr><td>dbfs:/databricks-datasets/COVID/coronavirusdataset/SeoulFloating.csv</td><td>SeoulFloating.csv</td><td>49682281</td><td>1595191981000</td></tr><tr><td>dbfs:/databricks-datasets/COVID/coronavirusdataset/Time.csv</td><td>Time.csv</td><td>6604</td><td>1595191981000</td></tr><tr><td>dbfs:/databricks-datasets/COVID/coronavirusdataset/TimeAge.csv</td><td>TimeAge.csv</td><td>27114</td><td>1595191981000</td></tr><tr><td>dbfs:/databricks-datasets/COVID/coronavirusdataset/TimeGender.csv</td><td>TimeGender.csv</td><td>6973</td><td>1595191981000</td></tr><tr><td>dbfs:/databricks-datasets/COVID/coronavirusdataset/TimeProvince.csv</td><td>TimeProvince.csv</td><td>92028</td><td>1595191981000</td></tr><tr><td>dbfs:/databricks-datasets/COVID/coronavirusdataset/Weather.csv</td><td>Weather.csv</td><td>1500573</td><td>1595191981000</td></tr><tr><td>dbfs:/databricks-datasets/COVID/coronavirusdataset/coronavirusdataset-readme.md</td><td>coronavirusdataset-readme.md</td><td>1786</td><td>1595191981000</td></tr><tr><td>dbfs:/databricks-datasets/COVID/coronavirusdataset/coronavirusdataset.zip</td><td>coronavirusdataset.zip</td><td>0</td><td>1587005067000</td></tr></tbody></table></div>

# %%
Arquivo ="dbfs:/databricks-datasets/COVID/coronavirusdataset/SearchTrend.csv"
spark.read.csv(Arquivo,header=True , inferSchema=True ).show(5)
# Out:
# +----------+-------+-------+---------+-----------+
# |      date|   cold|    flu|pneumonia|coronavirus|
# +----------+-------+-------+---------+-----------+
# |2016-01-01|0.11663| 0.0559|  0.15726|    0.00736|
# |2016-01-02|0.13372|0.17135|  0.20826|     0.0089|
# |2016-01-03|0.14917|0.22317|  0.19326|    0.00845|
# |2016-01-04|0.17463|0.18626|  0.29008|    0.01145|
# |2016-01-05|0.17226|0.15072|  0.24562|    0.01381|
# +----------+-------+-------+---------+-----------+
# only showing top 5 rows
